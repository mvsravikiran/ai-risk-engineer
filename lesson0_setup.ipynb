# %% [markdown]
# <a href="https://colab.research.google.com/github/mvsravikiran/ai-risk-engineer/blob/main/lesson0_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("My risk engineering journey starts now")
2 + 2
# Out:
# My risk engineering journey starts now
# 4
